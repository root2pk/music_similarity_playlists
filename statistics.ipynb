# %% [markdown]
# ## Jupyter notebook to plot statistical distributions of the music collection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read genre_predictions.csv and plot distribution of genres usng seaborn
df = pd.read_csv('genre_predictions.csv', usecols = [3], header = None)
df.columns = ['Parent Genre']
sns.displot(data=df, x='Parent Genre')
sns.rugplot(data=df, x='Parent Genre')
plt.title('Distribution of Parent Genres')
plt.xticks(rotation=45)
plt.xlabel(None)
plt.show()

# %%
# Extract specific genre predictions from genre_predictions.csv
df = pd.read_csv('genre_predictions.csv', usecols = [2], header = None)
df.columns = ['Genre']
# Save the extracted genre predictions and number of occurrences to a new tsv file
df['Genre'].value_counts().to_csv('genre_counts.tsv', sep='\t', header = ['Count'])

# %% [markdown]
# #### Tempo distribution

# %%
# Plot tempo distribution
df = pd.read_csv('features.csv', usecols = [1], header = None)
df.columns = ['Tempo']
sns.histplot(data=df, x='Tempo', kde=True)
sns.rugplot(data=df, x='Tempo')
plt.title('Tempo distribution')
plt.xlabel('Tempo (bpm)')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# #### Danceability distribution

# %%
# Plot danceability distribution
df = pd.read_csv('features.csv', usecols = [10], header = None)
df.columns = ['Danceability']
sns.histplot(data=df, x='Danceability', kde=True)
sns.rugplot(data=df, x='Danceability')
plt.title('Danceability distribution')
plt.xlabel('Danceability (0-1)')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# #### Key and Scale distribution
# ##### 1) Temperley

# %%
# Plot key and scale distribution - Temperley
df = pd.read_csv('features.csv', usecols = [2,3], header = None)
df.columns = ['key', 'scale']
# Combine key and scale into one column
df['Key and Scale'] = df['key'] + ' ' + df['scale']
sns.histplot(data=df, x='Key and Scale')
plt.title('Key and Scale distribution - Temperley')
plt.xlabel('Key and Scale')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# ##### 2) Krumhansl

# %%
# Plot key and scale distribution - Krumhansl
df = pd.read_csv('features.csv', usecols = [4, 5], header=None)
df.columns = ['key', 'scale']
# Combine key and scale into one column
df['Key and Scale'] = df['key'] + ' ' + df['scale']
sns.histplot(data=df, x='Key and Scale')
plt.title('Key and Scale distribution - Krumhansl')
plt.xlabel('Key and Scale')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# ##### 3) Edma

# %%
# Plot key and scale distribution - Edma
df = pd.read_csv('features.csv', usecols = [6, 7], header=None)
df.columns = ['key', 'scale']
# Combine key and scale into one column
df['Key and Scale'] = df['key'] + ' ' + df['scale']
sns.histplot(data=df, x='Key and Scale')
plt.title('Key and Scale distribution - Edma')
plt.xlabel('Key and Scale')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# #### Loudness Distribution

# %%
# Plot loudness distribution
df = pd.read_csv('features.csv', usecols = [8], header = None)
df.columns = ['Loudness']
sns.histplot(data=df, x='Loudness', kde=True)
sns.rugplot(data=df, x='Loudness')
plt.title('Loudness distribution')
plt.xlabel('Loudness (LUFS)')
plt.ylabel('Number of tracks')
plt.show()

# %% [markdown]
# ##### Arousal and Valence

# %%
# Plot arousal and valence in a 2D distribution
df = pd.read_csv('features.csv', usecols=[11, 12], header=None)
df.columns = ['Arousal', 'Valence']

# Subtract 5 from both 'Arousal' and 'Valence' columns, since range is 1 - 9
df['Arousal'] = df['Arousal'] - 5
df['Valence'] = df['Valence'] - 5

# Plot the scatter plot
ax = sns.scatterplot(data=df, x='Valence', y='Arousal')

plt.title('Arousal and Valence distribution', pad=15)
plt.xlabel('Valence')
plt.ylabel('Arousal')
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.axvline(x=0, color='r', linestyle='--')
plt.axhline(y=0, color='r', linestyle='--')

# Add labels
ax.text(4, 0, 'positive', ha='center', va='center', bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))
ax.text(-4, 0, 'negative', ha='center', va='center', bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))
ax.text(0, 4, 'high', ha='center', va='center', bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))
ax.text(0, -4, 'low', ha='center', va='center', bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))
ax.text(0, 0, 'neutral', ha='center', va='center', bbox=dict(facecolor='white', edgecolor='white', boxstyle='round'))

plt.show()

# %% [markdown]
# #### Voice/Instrumental distribution

# %%
# Plot distribution of voice/instrumental tracks
df = pd.read_csv('features.csv', usecols = [9], header = None)
df.columns = ['Voice/Instrumental']
sns.histplot(data=df, x='Voice/Instrumental', shrink = 0.8)
plt.title('Distribution of Voice/Instrumental tracks')
plt.xticks(rotation=0)
plt.ylabel('Number of tracks')
plt.show()
